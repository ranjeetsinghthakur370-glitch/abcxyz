# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjeetsinghthakur370-glitch/abcxyz/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(hrllo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6605/1611402366.py in <cell line: 0>()
# ----> 1 print(hrllo)
#
# NameError: name 'hrllo' is not defined

# %% [markdown]
# dfghjk

# %%
print('h')
# Out:
# h

# %%
print('wqaesrdyghuji')
# Out:
# wqaesrdyghuji

# %% [markdown]
# iuytdfghjhvcgu87trdfhkzdxfvmctyvu ifd k
